# %%
# !pip install plotly
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\users\soumm\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import plotly as plt

# %%
df = pd.read_csv("data/doge_data.csv")

df.head()
# Out:
#                     Datetime      Open      High       Low     Close  \
# 0  2020-12-31 23:00:00+00:00  0.004672  0.004704  0.004648  0.004683
# 1  2021-01-01 00:00:00+00:00  0.004681  0.004703  0.004615  0.004693
# 2  2021-01-01 01:00:00+00:00  0.004693  0.004752  0.004689  0.004739
# 3  2021-01-01 02:00:00+00:00  0.004738  0.004752  0.004729  0.004750
# 4  2021-01-01 03:00:00+00:00  0.004750  0.004983  0.004750  0.004978
#
#    Adj Close   Volume
# 0   0.004683        0
# 1   0.004693        0
# 2   0.004739        0
# 3   0.004750        0
# 4   0.004978  9477800

# %%
df.head()
# Out:
#                     Datetime      Open      High       Low     Close  \
# 0  2020-12-31 23:00:00+00:00  0.004672  0.004704  0.004648  0.004683
# 1  2021-01-01 00:00:00+00:00  0.004681  0.004703  0.004615  0.004693
# 2  2021-01-01 01:00:00+00:00  0.004693  0.004752  0.004689  0.004739
# 3  2021-01-01 02:00:00+00:00  0.004738  0.004752  0.004729  0.004750
# 4  2021-01-01 03:00:00+00:00  0.004750  0.004983  0.004750  0.004978
#
#    Adj Close   Volume
# 0   0.004683        0
# 1   0.004693        0
# 2   0.004739        0
# 3   0.004750        0
# 4   0.004978  9477800

# %%
#reset index
df = df.set_index('Datetime')

# %%
df
# Out:
#                                Open      High       Low     Close  Adj Close  \
# Datetime
# 2020-12-31 23:00:00+00:00  0.004672  0.004704  0.004648  0.004683   0.004683
# 2021-01-01 00:00:00+00:00  0.004681  0.004703  0.004615  0.004693   0.004693
# 2021-01-01 01:00:00+00:00  0.004693  0.004752  0.004689  0.004739   0.004739
# 2021-01-01 02:00:00+00:00  0.004738  0.004752  0.004729  0.004750   0.004750
# 2021-01-01 03:00:00+00:00  0.004750  0.004983  0.004750  0.004978   0.004978
# ...                             ...       ...       ...       ...        ...
# 2021-04-01 18:00:00+00:00  0.058733  0.059011  0.057618  0.058724   0.058724
# 2021-04-01 19:00:00+00:00  0.058836  0.059053  0.058329  0.058545   0.058545
# 2021-04-01 20:00:00+00:00  0.058543  0.060973  0.058543  0.059997   0.059997
# 2021-04-01 21:00:00+00:00  0.059989  0.059989  0.059005  0.059294   0.059294
# 2021-04-01 22:00:00+00:00  0.059358  0.060634  0.059358  0.060175   0.060175
#
# ...

# %%
fig = plt.graph_objects.Figure(plt.graph_objects.Candlestick(x=df.index, 
                                     open=df['Open'], 
                                     high=df['High'], 
                                     low=df['Low'], 
                                     close=df['Close'], name='market data'))
fig.update_layout(
    title='DOGE-USD live share price evolution',
    yaxis_title='Stock price (USD per DOGE)'
)
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
                      dict(count=15, label='15h', step='hour', stepmode='backward'),
                      dict(count=30, label='30h', step='hour', stepmode='backward'),
                      dict(count=1, label='HTD', step='hour', stepmode='todate'),
                      dict(count=3, label='3d', step='day', stepmode='backward'),
                      dict(step='all')
        ])
    )
)
fig.show()

# %%
import plotly.express as px

fig = px.line(df, y="High")
fig.add_scatter(x=df.index,y=df["Low"])
fig.show()
